# %% [markdown]
# # Seaborn
# is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.

# %%
#pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\gamakaai\anaconda\lib\site-packages (0.13.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\gamakaai\anaconda\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in d:\gamakaai\anaconda\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\gamakaai\anaconda\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\gamakaai\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\gamakaai\anaconda\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\gamakaai\anaconda\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\gamakaai\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend: With this backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %% [markdown]
# # 1. Numerical Data Ploting
#
# - relplot()
#
# - scatterplot()
#
# - lineplot()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import pandas as pd

# %%
tips = sns.load_dataset('tips') #default dataset
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Styles theme : darkgrid, whitegrid, dark, white, ticks}

# %%
sns.set(style="darkgrid")
#sns.set(style="whitegrid")
#sns.set(style="dark")
#sns.set(style="white")
#sns.set(style="ticks")

# %% [markdown]
# # relational plot

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %% [markdown]
# # Hue
# We can add another dimension in our plot with the help of hue as it gives color to the points and each color has some meaning attached to it.
#
# The hue semantic is categorical. That’s why it has a different color palette. If the hue semantic is numeric, then the coloring becomes sequential.

# %%
sns.set(style='darkgrid')
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
sns.set(style='darkgrid')
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'size')

# %%
sns.set(style = 'darkgrid')
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', 
            style = 'time', size = 'size')

# %% [markdown]
# # Line Plot

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500),value = randn(500).cumsum())) #Random Data Genrated

# %%
df.head()
# Out:
#    time     value
# 0     0 -2.195938
# 1     1 -3.613948
# 2     2 -4.611015
# 3     3 -4.943104
# 4     4 -5.345261

# %%
g=sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
g.fig.autofmt_xdate(rotation=90)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
# The seaborn ci code simply computes the percentile limits. 
#The actual mean, the standard deviation, etc. will appear in the percentiles routine
#Size of confidence intervals to draw around estimated values.
#If “sd”,  draw the standard deviation of the observations.

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar=('ci', 95) )

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', 
             data = fmri, markers = True,errorbar=('ci', 68), err_style='bars')#band
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', 
                data = tips, 
                hue = 'smoker',
                size = 'size',
                style = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = iris['sepal_length'], y = iris['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
